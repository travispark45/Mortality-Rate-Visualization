# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
% matplotlib inline

sns.set(style = 'darkgrid')

# %%
m = pd.read_csv('C:\\Users\\Travis Park\\Downloads\\us-countylevel-mortality\\mort.csv')
list(m.columns)
# Out:
# ['Location',
#  'FIPS',
#  'Category',
#  'Mortality Rate, 1980*',
#  'Mortality Rate, 1980* (Min)',
#  'Mortality Rate, 1980* (Max)',
#  'Mortality Rate, 1985*',
#  'Mortality Rate, 1985* (Min)',
#  'Mortality Rate, 1985* (Max)',
#  'Mortality Rate, 1990*',
#  'Mortality Rate, 1990* (Min)',
#  'Mortality Rate, 1990* (Max)',
#  'Mortality Rate, 1995*',
#  'Mortality Rate, 1995* (Min)',
#  'Mortality Rate, 1995* (Max)',
#  'Mortality Rate, 2000*',
#  'Mortality Rate, 2000* (Min)',
#  'Mortality Rate, 2000* (Max)',
#  'Mortality Rate, 2005*',
#  'Mortality Rate, 2005* (Min)',
#  'Mortality Rate, 2005* (Max)',
#  'Mortality Rate, 2010*',
#  'Mortality Rate, 2010* (Min)',
#  'Mortality Rate, 2010* (Max)',
#  'Mortality Rate, 2014*',
#  'Mortality Rate, 2014* (Min)',
#  'Mortality Rate, 2014* (Max)',
#  '% Change in Mortality Rate, 1980-2014',
#  '% Change in Mortality Rate, 1980-2014 (Min)',
#  '% Change in Mortality Rate, 1980-2014 (Max)']

# %% [markdown]
# We have a lot of columns that we will not use.  Rather than type out all the name, I made a list and deleted the ones I didnt want.  We can then iterate through the column names and only keep desired columns.
#
# Also dropping rows that have aggregates in them already.

# %%
tokeep = ['Location',
 'FIPS',
 'Category',
 'Mortality Rate, 1980*',
 'Mortality Rate, 1985*',
 'Mortality Rate, 1990*',
 'Mortality Rate, 1995*',
 'Mortality Rate, 2000*',
 'Mortality Rate, 2005*',
 'Mortality Rate, 2010*',
 'Mortality Rate, 2014*',]

m = m[(m.Location.str.contains(',') == True)]
m.reset_index(drop=True, inplace=True)

# %%
x = 0
while x < len(m.columns):
    if m.columns[x] not in tokeep:
        m = m.drop(m.columns[x],1)
    x=x+1
m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65982 entries, 0 to 65981
# Data columns (total 20 columns):
# Location                                       65982 non-null object
# FIPS                                           65982 non-null float64
# Category                                       65982 non-null object
# Mortality Rate, 1980*                          65982 non-null float64
# Mortality Rate, 1980* (Max)                    65982 non-null float64
# Mortality Rate, 1985*                          65982 non-null float64
# Mortality Rate, 1985* (Max)                    65982 non-null float64
# Mortality Rate, 1990*                          65982 non-null float64
# Mortality Rate, 1990* (Max)                    65982 non-null float64
# Mortality Rate, 1995*                          65982 non-null float64
# Mortality Rate, 1995* (Max)                    65982 non-null float64
# Mortality Rate, 2000*                          65982 non-null float64
# Mortality Rate, 2000* (Max)                    65982 non-null float64
# Mortality Rate, 2005*                          65982 non-null float64
# Mortality Rate, 2005* (Max)                    65982 non-null float64
# Mortality Rate, 2010*                          65982 non-null float64
# Mortality Rate, 2010* (Max)                    65982 non-null float64
# Mortality Rate, 2014*                          65982 non-null float64
# Mortality Rate, 2014* (Max)                    65982 non-null float64
# % Change in Mortality Rate, 1980-2014 (Min)    65982 non-null float64
# dtypes: float64(18), object(2)
# memory usage: 10.1+ MB

# %% [markdown]
# This splits the county and state.  Adds each to a new column

# %%
m['County'] = ''
m['State'] = ''

county = []
state = []

x=0
while x<len(m):
    p = m['Location'][x].index(',')
    county.append(m['Location'][x][:p])
    state.append(m['Location'][x][p+2:])
    x=x+1

# %%
m['County'] = county
m['State'] = state

# %%
m.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65982 entries, 0 to 65981
# Data columns (total 22 columns):
# Location                                       65982 non-null object
# FIPS                                           65982 non-null float64
# Category                                       65982 non-null object
# Mortality Rate, 1980*                          65982 non-null float64
# Mortality Rate, 1980* (Max)                    65982 non-null float64
# Mortality Rate, 1985*                          65982 non-null float64
# Mortality Rate, 1985* (Max)                    65982 non-null float64
# Mortality Rate, 1990*                          65982 non-null float64
# Mortality Rate, 1990* (Max)                    65982 non-null float64
# Mortality Rate, 1995*                          65982 non-null float64
# Mortality Rate, 1995* (Max)                    65982 non-null float64
# Mortality Rate, 2000*                          65982 non-null float64
# Mortality Rate, 2000* (Max)                    65982 non-null float64
# Mortality Rate, 2005*                          65982 non-null float64
# Mortality Rate, 2005* (Max)                    65982 non-null float64
# Mortality Rate, 2010*                          65982 non-null float64
# Mortality Rate, 2010* (Max)                    65982 non-null float64
# Mortality Rate, 2014*                          65982 non-null float64
# Mortality Rate, 2014* (Max)                    65982 non-null float64
# % Change in Mortality Rate, 1980-2014 (Min)    65982 non-null float64
# County                                         65982 non-null object
# State                                          65982 non-null object
# dtypes: float64(18), object(4)
# memory usage: 11.1+ MB

# %% [markdown]
# Now that we have all the columns we want, we need to un pivot the data into a more useful format.

# %%
n = pd.melt(m, id_vars = ['Location','FIPS','Category','County','State'], value_vars = ['Mortality Rate, 1980*',
                                                                                    'Mortality Rate, 1985*',
                                                                                   'Mortality Rate, 1990*',
                                                                                   'Mortality Rate, 1995*',
                                                                                   'Mortality Rate, 2000*',
                                                                                   'Mortality Rate, 2005*',
                                                                                   'Mortality Rate, 2010*',
                                                                                   'Mortality Rate, 2014*',])
n=n.rename(columns = {'value':'Mortality Rate'})

x=0
year = []
while x<len(n):
    year.append(n['variable'][x][16:20])
    x=x+1
    
n['Year'] = year
n.Year = n.Year.astype(float)
n=n.drop('variable',1)

# %%
y = sorted(list(n['State'].unique()))

plt.figure(figsize = (15,3))
sns.violinplot(y = 'Mortality Rate', x = 'State', data = n[(n['Year'] == 2014)], inner = 'quartile', 
               palette = 'Set2', order = y)

# %% [markdown]
# This shows a severe skew in the data.  To visualize a little better we will unskew it and graph the states on the y axis.

# %%
n['Sk Mortality Rate']= np.log1p(n['Mortality Rate'])

# %%
y = sorted(list(n['State'].unique()))

plt.figure(figsize = (3,15))
sns.violinplot(x = 'Sk Mortality Rate', y = 'State', data = n[(n['Year'] == 2014)], inner = 'quartile', 
               palette = 'Set2', order = y)

# %% [markdown]
# Too look at mortality rates correlations we will use a correlation matrix.  The matrix compares variables, so we need to pivot the data to look at Category as the columns.
#
# First I am going to clean up some of the column names to make them fit better on the screen.

# %%
o = pd.pivot_table(n[(n['Year'] == 2014)], values = 'Mortality Rate', index = ['County','Year','State'], 
                   columns = 'Category', aggfunc = np.mean)
    

ocols = ['Cardiovascular',
 'Chronic resp',
 'Chronic liver',
 'Diabetes',
 'Diarrhea',
 'Digestive diseases',
 'Non Natural',
 'HIV/AIDS and TB',
 'Maternal disorders',
 'Mental disorders',
 'Musculoskeletal disorders',
 'Tropical diseases',
 'Neonatal disorders',
 'Neoplasms',
 'Neurological disorders',
 'Nutritional deficiencies',
 'Other communicable',
 'Other non-communicable',
 'Violence',
 'Transport injuries',
 'Unintentional injuries']


o.columns = ocols
o.head()
# Out:
#                                         Cardiovascular  Chronic resp  \
# County           Year   State
# Abbeville County 2014.0 South Carolina          252.42         59.27
# Acadia Parish    2014.0 Louisiana               363.23         56.09
# Accomack County  2014.0 Virginia                272.88         60.31
# Ada County       2014.0 Idaho                   211.01         54.67
# Adair County     2014.0 Iowa                    270.87         47.06
#
#                                         Chronic liver  Diabetes  Diarrhea  \
# County           Year   State
# Abbeville County 2014.0 South Carolina          20.16     57.49     30.22
# Acadia Parish    2014.0 Louisiana               19.36     68.58     48.68
# Accomack County  2014.0 Virginia                17.89     69.63     39.83
# Ada County       2014.0 Idaho                   15.20     42.20     17.79
# Adair County     2014.0 Iowa                    12.03     51.62     46.29
#
#                                         Digestive diseases  Non Natural  \
# County           Year   State
# Abbeville County 2014.0 South Carolina               15.86         0.06
# Acadia Parish    2014.0 Louisiana                    14.86         0.09
# Accomack County  2014.0 Virginia                     14.09         0.08
# Ada County       2014.0 Idaho                        15.07         0.03
# Adair County     2014.0 Iowa                         17.04         0.05
#
#                                         HIV/AIDS and TB  Maternal disorders  \
# County           Year   State
# Abbeville County 2014.0 South Carolina             1.96                0.52
# Acadia Parish    2014.0 Louisiana                  3.18                0.68
# Accomack County  2014.0 Virginia                   3.24                0.50
# Ada County       2014.0 Idaho                      0.56                0.26
# Adair County     2014.0 Iowa                       0.38                0.27
#
#                                         Mental disorders  \
# County           Year   State
# Abbeville County 2014.0 South Carolina             11.14
# Acadia Parish    2014.0 Louisiana                  13.62
# Accomack County  2014.0 Virginia                   13.53
# Ada County       2014.0 Idaho                      10.58
# Adair County     2014.0 Iowa                        6.46
#
#                                                  ...            \
# County           Year   State                    ...
# Abbeville County 2014.0 South Carolina           ...
# Acadia Parish    2014.0 Louisiana                ...
# Accomack County  2014.0 Virginia                 ...
# Ada County       2014.0 Idaho                    ...
# Adair County     2014.0 Iowa                     ...
#
#                                         Tropical diseases  Neonatal disorders  \
# County           Year   State
# Abbeville County 2014.0 South Carolina               0.05                5.11
# Acadia Parish    2014.0 Louisiana                    0.09                4.59
# Accomack County  2014.0 Virginia                     0.05                4.74
# Ada County       2014.0 Idaho                        0.06                2.15
# Adair County     2014.0 Iowa                         0.06                2.07
#
#                                         Neoplasms  Neurological disorders  \
# County           Year   State
# Abbeville County 2014.0 South Carolina     216.66                  116.88
# Acadia Parish    2014.0 Louisiana          266.67                  124.63
# Accomack County  2014.0 Virginia           254.18                  135.23
# Ada County       2014.0 Idaho              171.72                  120.21
# Adair County     2014.0 Iowa               194.81                   83.72
#
#                                         Nutritional deficiencies  \
# County           Year   State
# Abbeville County 2014.0 South Carolina                      2.55
# Acadia Parish    2014.0 Louisiana                           2.44
# Accomack County  2014.0 Virginia                            1.28
# Ada County       2014.0 Idaho                               1.36
# Adair County     2014.0 Iowa                                0.91
#
#                                         Other communicable  \
# County           Year   State
# Abbeville County 2014.0 South Carolina                1.43
# Acadia Parish    2014.0 Louisiana                     1.53
# Accomack County  2014.0 Virginia                      1.61
# Ada County       2014.0 Idaho                         1.18
# Adair County     2014.0 Iowa                          0.96
#
#                                         Other non-communicable  Violence  \
# County           Year   State
# Abbeville County 2014.0 South Carolina                    8.11     21.92
# Acadia Parish    2014.0 Louisiana                         8.60     31.00
# Accomack County  2014.0 Virginia                          7.41     24.50
# Ada County       2014.0 Idaho                             5.80     18.82
# Adair County     2014.0 Iowa                              5.58     17.58
#
#                                         Transport injuries  \
# County           Year   State
# Abbeville County 2014.0 South Carolina               21.34
# Acadia Parish    2014.0 Louisiana                    29.63
# Accomack County  2014.0 Virginia                     26.82
# Ada County       2014.0 Idaho                        10.20
# Adair County     2014.0 Iowa                         22.11
#
#                                         Unintentional injuries
# County           Year   State
# Abbeville County 2014.0 South Carolina                   23.24
# Acadia Parish    2014.0 Louisiana                        23.57
# Accomack County  2014.0 Virginia                         21.88
# Ada County       2014.0 Idaho                            17.30
# Adair County     2014.0 Iowa                             24.82
#
# [5 rows x 21 columns]

# %% [markdown]
# Building the correlation matrix
#
# The matrix is mirrored across the diagonal line, so I went ahead and hid the top part to avoid confusion.  Dark red squares mean that it is highly correlated.

# %%
corr = o.corr()
fg, ax = plt.subplots(figsize = (11,9))

mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

sns.heatmap(corr, mask = mask, linewidths = .5, square = True)

# %% [markdown]
# Neoplasms and Cardiovascular disease are very highly correlated.  Let's look at a scatter plot of just those two.
#
# Adding a kde and bar graphs on the edges helps us understand the concentration of points in the center.

# %%
sns.set(style = 'ticks')
p = (sns.jointplot(o['Neoplasms'], o['Cardiovascular'],
                  stat_func=None,edgecolor="w",xlim = (0,550), ylim = (0,550))
     .plot_joint(sns.kdeplot, zorder = 1, n_levels = 10))

# %% [markdown]
# Zooming back out from those two diseases, lets look at some or the relationships between other diseases.
#
# Because the top and bottom corners are mirror images, we changed the bottom to a kde plot to get a better understanding of the density of values in the concentrations.

# %%
p=o.ix[:,:5]
sns.set(style = 'darkgrid')
g = sns.PairGrid(p)
g.map_upper(plt.scatter, s = 5)
g.map_diag(plt.hist, lw = 0, edgecolor = 'w')
g.map_lower(sns.kdeplot, cmap = 'Blues_d')

g.set(ylim = (0,None))
g.set(xlim = (0,None))

# %% [markdown]
# *Cardiovascular Analysis*
#
# Let's make a table with only cardiovascular diseases but with multiple years.  Because there are many counties in each state, so we will take the average for the state per year.

# %%
cardio = n[(n['Category'] == 'Cardiovascular diseases')]
cardio = cardio[['Year','State','Mortality Rate']]
cardio = cardio.groupby(['Year','State']).mean()
cardio.reset_index(level=0, inplace=True)
cardio.reset_index(level=0, inplace=True)
cardio.head()
# Out:
#         State    Year  Mortality Rate
# 0     Alabama  1980.0      526.954328
# 1      Alaska  1980.0      480.126207
# 2     Arizona  1980.0      411.335333
# 3    Arkansas  1980.0      522.188400
# 4  California  1980.0      455.754483

# %% [markdown]
# We can use this table to see the year over year change in mortality rates of cardiovascular disease.
#
# We can see that mortality rates are dropping in every state.

# %%
grid = sns.FacetGrid(cardio, col = 'State', hue = 'State', col_wrap = 5, size = 2)

grid.map(plt.plot, 'Year', 'Mortality Rate',ms = 4, marker ='o')

grid.set(xlim=(1980, 2014), ylim = (0,None))

grid.set_xticklabels(rotation = 45)

grid.fig.tight_layout(w_pad = 1)

# %% [markdown]
# The last chart showed us that there was a general decline in mortality rate, but it wasn't clear on how each state was doing relative to each other.
#
# For this we will find the % change in mortality rates for cardiovascular disease from 1980 to 2014.
#
# To do this will will need to reshape our table to do that calculation easily.

# %%
cardio = pd.pivot_table(cardio, values = 'Mortality Rate', index = ['State'], 
                   columns = 'Year', aggfunc = np.mean)

cardio.reset_index(level=0, inplace=True)

# %%
cardio.columns = ['State','One','Two','Three','Four','Five','Sx','Seven','Eight']
#changing columns because I could not call when the column name was a year number

# %%
cardio['Delta'] = ''
delta = []
x=0
while x < len(cardio):
    y = cardio['One'][x] 
    z = cardio['Eight'][x]
    delta.append((z-y)/y)
    
    x=x+1

cardio['Delta'] = delta
    
cardio.head()
# Out:
#         State         One         Two       Three        Four        Five  \
# 0     Alabama  526.954328  498.024179  450.712090  436.220896  415.470448
# 1      Alaska  480.126207  419.686897  356.804828  333.187241  306.607241
# 2     Arizona  411.335333  379.146667  335.766667  316.097333  285.434000
# 3    Arkansas  522.188400  495.439067  453.963333  445.558667  427.723467
# 4  California  455.754483  424.305345  375.381207  351.722759  325.205517
#
#            Sx       Seven       Eight     Delta
# 0  369.677612  328.869104  329.501343 -0.374706
# 1  257.860690  222.537586  222.845172 -0.535861
# 2  252.837333  219.314000  217.806667 -0.470489
# 3  383.091867  345.631067  349.178400 -0.331317
# 4  279.154655  243.175172  237.626897 -0.478608

# %% [markdown]
# Now let's see which state has had the largest reduction in mortality rate.
#
# We are looking for the lowest number (high drop in mortality).
#
# Congrats Massachusetts!
#
# Further analysis might try to find some regional correlation to mortality rates decline.

# %%
sns.set(style="darkgrid")

#fg, ax = plt.subplots(figsize = (11,9))

g = sns.PairGrid(cardio.sort_values(by = 'Delta', ascending = True), x_vars = 'Delta', y_vars = 'State', size = 10, aspect = .4)

g.map(sns.stripplot, size = 10, orient = 'h', palette = 'coolwarm', edgecolor = 'w')

g.set(xlabel='', ylabel='')

titles = ['1980 - 2014 % Change']

for ax, title in zip(g.axes.flat, titles):

    # Set a different title for each axes
    ax.set(title=title)

    ax.xaxis.grid(False)
    ax.yaxis.grid(True)
